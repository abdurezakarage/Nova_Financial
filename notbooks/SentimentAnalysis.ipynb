# %%
import sys 
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from src.Sentiment import Raw_Analyst_Ratings
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_analyst_ratings = pd.read_csv('../data/raw_analyst_ratings.csv')

# %%
raw_analyst_ratings.columns
# Out:
# Index(['Unnamed: 0', 'headline', 'url', 'publisher', 'date', 'stock'], dtype='object')

# %%
Dataanalyser= Raw_Analyst_Ratings(raw_analyst_ratings,'A')

# %%
Dataanalyser.analyze_text_length()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  count    1.407328e+06
#  mean     7.312051e+01
#  std      4.073531e+01
#  min      3.000000e+00
#  25%      4.700000e+01
#  50%      6.400000e+01
#  75%      8.700000e+01
#  max      5.120000e+02
#  Name: headline_length, dtype: float64)

# %%
Dataanalyser.analyze_publisher_activity()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  publisher
#  Paul Quintaro        228373
#  Lisa Levin           186979
#  Benzinga Newsdesk    150484
#  Charles Gross         96732
#  Monica Gerson         82380
#  Eddie Staley          57254
#  Hal Lindon            49047
#  ETF Professor         28489
#  Juan Lopez            28438
#  Benzinga Staff        28114
#  Name: count, dtype: int64)

# %%
Dataanalyser.analyze_publisher_domains()
# Out:
# (<Figure size 1200x600 with 1 Axes>,
#  domain
#  benzinga.com              7937
#  gmail.com                  139
#  andyswan.com                 5
#  investdiva.com               2
#  tothetick.com                2
#  eosdetroit.io                1
#  forextraininggroup.com       1
#  stockmetrix.net              1
#  Name: count, dtype: int64)

# %%
Dataanalyser.analyze_publisher_content()
# Out:
# === Publisher Content Analysis ===
#
# Publisher: Paul Quintaro
# Total Articles: 228373
# Average Headline Length: 84.35 characters
# Date Range: 2011-05-17 00:00:00 to 2018-06-07 00:00:00
#
# Publisher: Lisa Levin
# Total Articles: 186979
# Average Headline Length: 47.50 characters
# Date Range: 2010-07-30 00:00:00 to 2020-06-11 12:19:17-04:00
#
# Publisher: Benzinga Newsdesk
# Total Articles: 150484
# Average Headline Length: 114.65 characters
# Date Range: 2015-01-15 00:00:00 to 2020-06-11 17:11:20-04:00
#
# Publisher: Charles Gross
# Total Articles: 96732
# Average Headline Length: 81.00 characters
# Date Range: 2011-11-08 00:00:00 to 2020-06-11 11:08:26-04:00
#
# Publisher: Monica Gerson
# Total Articles: 82380
# Average Headline Length: 51.00 characters
# Date Range: 2009-09-22 00:00:00 to 2017-10-03 00:00:00
# (<Figure size 1200x2000 with 5 Axes>,
#  {'Paul Quintaro': {'article_count': 228373,
#    'avg_headline_length': np.float64(84.34783884259522),
# ...

# %%
Dataanalyser.analyze_publication_trends()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  date
#  2009-02-14      1
#  2009-04-27      2
#  2009-04-29      1
#  2009-05-22      1
#  2009-05-27      6
#               ...
#  2020-06-07     25
#  2020-06-08    765
#  2020-06-09    803
#  2020-06-10    807
#  2020-06-11    544
#  Length: 3955, dtype: int64)

# %%
Dataanalyser.analyze_day_of_week()

Dataanalyser.analyze_publication_times()
# Out:
# === Publication Time Analysis ===
#
# Peak Publication Hour: 0:00 (1351472 articles)
# Average Articles per Hour: 58638.67
#
# Top 5 Most Active Hours:
# 0:00 - 1351472 articles
# 14:00 - 7669 articles
# 13:00 - 5965 articles
# 16:00 - 5732 articles
# 15:00 - 5701 articles
# (<Figure size 1200x1000 with 3 Axes>,
#  hour
#  0     1351472
#  1          82
#  2          48
#  3          27
#  4          67
#  5          14
#  6          57
#  7          93
#  8        1469
#  9        1829
#  10       2476
#  11       5033
#  12       5527
#  13       5965
#  14       7669
#  15       5701
#  16       5732
#  17       2710
#  18       2075
#  19       1612
#  20       3939
#  21       2800
#  22        704
#  23        227
#  Name: count, dtype: int64)

# %%
Dataanalyser.analyze_extreme_sentiments()
# Out:
# === Most Positive Headline ===
# Date: 2010-12-15 00:00:00+00:00
# Publisher: webmaster
# Headline: Best Buy: Analysts' Upgrades, Downgrades
# Sentiment Score: 1.000
#
# === Most Negative Headline ===
# Date: 2014-10-10 00:00:00+00:00
# Publisher: Jayson Derrick
# Headline: Tech, Semiconductors Among Worst Performers As Sell-Off Continues
# Sentiment Score: -1.000
# {'most_positive': date                        2010-12-15 00:00:00+00:00
#  publisher                                   webmaster
#  headline     Best Buy: Analysts' Upgrades, Downgrades
#  sentiment                                         1.0
#  Name: 819, dtype: object,
#  'most_negative': date                                 2014-10-10 00:00:00+00:00
#  publisher                                       Jayson Derrick
#  headline     Tech, Semiconductors Among Worst Performers As...
#  sentiment                                                 -1.0
#  Name: 2552, dtype: object}
